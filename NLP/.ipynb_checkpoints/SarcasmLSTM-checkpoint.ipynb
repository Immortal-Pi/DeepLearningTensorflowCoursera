# %% [markdown]
# # Training a Sarcasm Detection Model using Bidirectional LSTMs

# %% [markdown]
# - dataset : https://storage.googleapis.com/tensorflow-1-public/course3/sarcasm.json

# %%
import json

# %%
with open('datasets/sarcasm.json','rb') as f:
    datastore=json.load(f)

# %%
sentences=[]
labels=[]

# %%
for item in datastore:
    sentences.append(item['headline'])
    labels.append(item['is_sarcastic'])

# %%
training_size = 20000

# Split the sentences
training_sentences = sentences[0:training_size]
testing_sentences = sentences[training_size:]

# Split the labels
training_labels = labels[0:training_size]
testing_labels = labels[training_size:]

# %% [markdown]
# # data preprocessing

# %%
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

vocab_size = 10000
max_length = 120
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"

# Initialize the Tokenizer class
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)

# Generate the word index dictionary
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index

# Generate and pad the training sequences
training_sequences = tokenizer.texts_to_sequences(training_sentences)
training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# Generate and pad the testing sequences
testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# Convert the labels lists into numpy arrays
training_labels = np.array(training_labels)
testing_labels = np.array(testing_labels)

# %%
import tensorflow as tf

# Parameters
embedding_dim = 16
lstm_dim = 32
dense_dim = 24

# Model Definition with LSTM
model_lstm = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(lstm_dim)),
    tf.keras.layers.Dense(dense_dim, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Set the training parameters
model_lstm.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# Print the model summary
model_lstm.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 120, 16)           160000
#
#  bidirectional (Bidirectiona  (None, 64)               12544
#  l)
#
#  dense (Dense)               (None, 24)                1560
#
#  dense_1 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 174,129
# Trainable params: 174,129
# Non-trainable params: 0
# _________________________________________________________________

# %%
NUM_EPOCHS = 10

# Train the model
history_lstm = model_lstm.fit(training_padded, training_labels, epochs=NUM_EPOCHS, validation_data=(testing_padded, testing_labels))
# Out:
# Epoch 1/10
# 625/625 [==============================] - 16s 21ms/step - loss: 0.4118 - accuracy: 0.7996 - val_loss: 0.3360 - val_accuracy: 0.8542
# Epoch 2/10
# 625/625 [==============================] - 13s 20ms/step - loss: 0.2118 - accuracy: 0.9140 - val_loss: 0.3396 - val_accuracy: 0.8615
# Epoch 3/10
# 625/625 [==============================] - 13s 20ms/step - loss: 0.1295 - accuracy: 0.9528 - val_loss: 0.4180 - val_accuracy: 0.8521
# Epoch 4/10
# 625/625 [==============================] - 13s 20ms/step - loss: 0.0739 - accuracy: 0.9751 - val_loss: 0.5363 - val_accuracy: 0.8438
# Epoch 5/10
# 625/625 [==============================] - 13s 20ms/step - loss: 0.0468 - accuracy: 0.9851 - val_loss: 0.6417 - val_accuracy: 0.8363
# Epoch 6/10
# 625/625 [==============================] - 13s 20ms/step - loss: 0.0301 - accuracy: 0.9915 - val_loss: 0.7515 - val_accuracy: 0.8381
# Epoch 7/10
# 625/625 [==============================] - 12s 20ms/step - loss: 0.0239 - accuracy: 0.9920 - val_loss: 0.8573 - val_accuracy: 0.8320
# Epoch 8/10
# 625/625 [==============================] - 13s 20ms/step - loss: 0.0173 - accuracy: 0.9946 - val_loss: 0.9892 - val_accuracy: 0.8317
# Epoch 9/10
# 625/625 [==============================] - 13s 20ms/step - loss: 0.0147 - accuracy: 0.9952 - val_loss: 0.8265 - val_accuracy: 0.8301
# Epoch 10/10
# 625/625 [==============================] - 13s 20ms/step - loss: 0.0102 - accuracy: 0.9972 - val_loss: 1.0929 - val_accuracy: 0.8328

# %%
import matplotlib.pyplot as plt

# Plot Utility
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

# Plot the accuracy and loss history
plot_graphs(history_lstm, 'accuracy')
plot_graphs(history_lstm, 'loss')

# %%
import io

embedding_layer=model_lstm.layers[0]
embedding_weights=embedding_layer.get_weights()[0]
print(embedding_weights.shape)
reverse_word_index=tokenizer.index_word
out_v=io.open('datasets/sarcasm1_vect.tsv','w',encoding='utf-8')
out_m=io.open('datasets/sarcasm1_meta.tsv','w',encoding='utf-8')

for word_num in range(1, vocab_size):
    word_name=reverse_word_index[word_num]
    word_embedding=embedding_weights[word_num]
    out_m.write(word_name+'\n')
    out_v.write('\t'.join([str(x) for x in word_embedding])+'\n')
out_v.close()
out_m.close()
# Out:
# (10000, 16)

# %%
import tensorflow as tf

# Parameters
embedding_dim = 16
filters = 128
kernel_size = 5
dense_dim = 6

# Model Definition with Conv1D
model_conv = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Conv1D(filters, kernel_size, activation='relu'),
    tf.keras.layers.GlobalMaxPooling1D(),
    tf.keras.layers.Dense(dense_dim, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Set the training parameters
model_conv.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# Print the model summary
model_conv.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 120, 16)           160000
#
#  conv1d (Conv1D)             (None, 116, 128)          10368
#
#  global_max_pooling1d (Globa  (None, 128)              0
#  lMaxPooling1D)
#
#  dense_2 (Dense)             (None, 6)                 774
#
#  dense_3 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 171,149
# Trainable params: 171,149
# Non-trainable params: 0
# _________________________________________________________________

# %%
NUM_EPOCHS = 10

# Train the model
history_conv = model_conv.fit(training_padded, training_labels, epochs=NUM_EPOCHS, validation_data=(testing_padded, testing_labels))
# Out:
# Epoch 1/10
# 625/625 [==============================] - 5s 5ms/step - loss: 0.4560 - accuracy: 0.7729 - val_loss: 0.3590 - val_accuracy: 0.8392
# Epoch 2/10
# 625/625 [==============================] - 3s 4ms/step - loss: 0.2386 - accuracy: 0.9048 - val_loss: 0.3592 - val_accuracy: 0.8477
# Epoch 3/10
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1313 - accuracy: 0.9530 - val_loss: 0.4283 - val_accuracy: 0.8407
# Epoch 4/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.0599 - accuracy: 0.9822 - val_loss: 0.5356 - val_accuracy: 0.8366
# Epoch 5/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.0248 - accuracy: 0.9937 - val_loss: 0.6458 - val_accuracy: 0.8317
# Epoch 6/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0109 - accuracy: 0.9978 - val_loss: 0.7407 - val_accuracy: 0.8354
# Epoch 7/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0054 - accuracy: 0.9991 - val_loss: 0.8298 - val_accuracy: 0.8323
# Epoch 8/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0031 - accuracy: 0.9994 - val_loss: 0.9030 - val_accuracy: 0.8334
# Epoch 9/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.9778 - val_accuracy: 0.8305
# Epoch 10/10
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 1.0330 - val_accuracy: 0.8295

# %%
import matplotlib.pyplot as plt

# Plot Utility
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

# Plot the accuracy and loss history
plot_graphs(history_conv, 'accuracy')
plot_graphs(history_conv, 'loss')
